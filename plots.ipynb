# %%
import matplotlib.pyplot as plt
from analysis import ELO
import pandas as pd
from plot_functions import *
import seaborn as sns

# %% [markdown]
# # Comparing Lichess vs Chesscom Userlist
# #### RD 50 is the standard Rating Deviation used

# %% [markdown]
# ### Blitz

# %%
plot("li_blitz", "ch_blitz", data_li, "Lichess Userlist", "black")
plot("li_blitz", "ch_blitz", data_ch, "Chesscom Userlist", "g")
plot("li_blitz", "ch_blitz", data_full, "Full Userlist", "purple")

# %% [markdown]
# ### Bullet

# %%
plot("li_bullet", "ch_bullet", data_li, "Lichess Userlist", "black")
plot("li_bullet", "ch_bullet", data_ch, "Chesscom Userlist", "g")
plot("li_bullet", "ch_bullet", data_full, "Full Userlist", "purple")

# %% [markdown]
# ### Rapid

# %%
plot("li_rapid", "ch_rapid", data_li, "Lichess Userlist", "black")
plot("li_rapid", "ch_rapid", data_ch, "Chesscom Userlist", "g")
plot("li_rapid", "ch_rapid", data_full, "Full Userlist", "purple")

# %% [markdown]
# I will be using Blitz as the main game mode to look at.

# %% [markdown]
# ## Difference RD (Rating Deviation makes)

# %%
plot("li_blitz", "ch_blitz", data_full, "RD = 45", "red", rd = 45)
plot("li_blitz", "ch_blitz", data_full, "RD = 50", "blue", rd = 50)
plot("li_blitz", "ch_blitz", data_full, "RD = 75", "green", rd = 75)
plot("li_blitz", "ch_blitz", data_full, "RD = 100", "purple", rd = 100)
plot("li_blitz", "ch_blitz", data_full, "No Filter on RD", "black", rd = 500)

# %% [markdown]
# ## Hex figure

# %%
hex1("li_blitz", "ch_blitz", rds=50)
hex2("li_blitz", "ch_blitz", rds=50)

# %% [markdown]
# ## Rating Distribution

# %%
dis("li_blitz", "Lichess User List", "li", "black")

# %%
dis("li_blitz", "Chesscom User List", "ch", "green")

# %% [markdown]
# ### Different differentials and their impact

# %%
plot_predict("li_blitz", "ch_blitz", "li", "red", rds=60, difs=100) 
plot_predict("li_blitz", "ch_blitz", "li", "blue", rds=60, difs=300) 
plot_predict("li_blitz", "ch_blitz", "li", "green", rds=60, difs=500) 
plot_predict("li_blitz", "ch_blitz", "li", "purple", rds=60, difs=800) 
plot_predict("li_blitz", "ch_blitz", "li", "black", rds=60, difs=1000)

# %% [markdown]
# ### User List prediction differences

# %%
plot_predict("li_blitz", "ch_blitz", "li", "blue", rds=60, difs=800, typ="user")
plot_predict("li_blitz", "ch_blitz", "ch", "red", rds=60, difs=800, typ="user")
plot_predict("li_blitz", "ch_blitz", "full", "green", rds=60, difs=800, typ="user")

# %% [markdown]
# ### Predictions

# %%
plt.title("Lichess Blitz vs Chesscom Elo Ratings")
plot_predict("li_blitz", "ch_blitz", "full", "blue", rds=60, difs=800, typ="scatter comp")
plot_predict("li_blitz", "ch_bullet", "full", "red", rds=60, difs=800, typ="scatter comp")
plot_predict("li_blitz", "ch_rapid", "full", "green", rds=60, difs=800, typ="scatter comp")

# %%
plt.title("Lichess Bullet vs Chesscom Elo Ratings")
plot_predict("li_bullet", "ch_blitz", "full", "blue", rds=60, difs=800, typ="scatter comp")
plot_predict("li_bullet", "ch_bullet", "full", "red", rds=60, difs=800, typ="scatter comp")
plot_predict("li_bullet", "ch_rapid", "full", "green", rds=60, difs=800, typ="scatter comp")

# %%
plt.title("Chesscom Blitz vs Lichess Elo Ratings")
plot_predict("ch_blitz", "li_blitz", "full", "blue", rds=60, difs=800, typ="scatter comp")
plot_predict("ch_blitz", "li_bullet", "full", "red", rds=60, difs=800, typ="scatter comp")
plot_predict("ch_blitz", "li_rapid", "full", "green", rds=60, difs=800, typ="scatter comp")

# %%
plt.title("Chesscom Bullet vs Lichess Elo Ratings")
plot_predict("ch_bullet", "li_blitz", "full", "blue", rds=60, difs=800, typ="scatter comp")
plot_predict("ch_bullet", "li_bullet", "full", "red", rds=60, difs=800, typ="scatter comp")
plot_predict("ch_bullet", "li_rapid", "full", "green", rds=60, difs=800, typ="scatter comp")

# %%
plt.title("Lichess Blitz vs Lichess Elo Ratings")
plot_predict("li_blitz", "li_bullet", "full", "red", rds=60, difs=800, typ="scatter comp")
plot_predict("li_blitz", "li_rapid", "full", "green", rds=60, difs=800, typ="scatter comp")

# %%
plt.title("Chesscom Blitz vs Chesscom Elo Ratings")
plot_predict("ch_blitz", "ch_bullet", "full", "red", rds=60, difs=800, typ="scatter comp")
plot_predict("ch_blitz", "ch_rapid", "full", "green", rds=60, difs=800, typ="scatter comp")
